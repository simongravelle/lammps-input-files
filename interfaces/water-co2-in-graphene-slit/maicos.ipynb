# %%
from maicos import DensityPlanar, Diporder
import numpy as np
import MDAnalysis as mda
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator

# %%
fontsize = 25
fontlegende = 22
font = {'family': 'sans', 'color':  'black', 
        'weight': 'normal', 'size': fontsize}
my_color_1 = np.array([0.090, 0.247, 0.560])
my_color_2 = np.array([0.235, 0.682, 0.639])
my_color_3 = np.array([1.000, 0.509, 0.333])
my_color_4 = np.array([0.588, 0.588, 0.588])
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Palatino"],
})

# %%
u = mda.Universe('solvated.data', 'prod.xtc')
total_frame = u.trajectory.n_frames

# %%
cpt = 0
for mystop in np.arange(2, total_frame, 2):
    # import universe and create groups
    u = mda.Universe('solvated.data', 'prod.xtc')
    u.transfer_to_memory(stop = mystop)
    #u.add_TopologyAttr('name', ['C']*np.sum(u.atoms.types == '3') 
    #                   + ['O', 'H1', 'H2']*np.sum(u.atoms.types == '1'))
    group_H2O = u.select_atoms('type 1 2')
    group_CO2 = u.select_atoms('type 3 4')
    group_CAR = u.select_atoms('type 5')
    group_FLU = u.select_atoms('type 1 2 3 4')

    # density profile
    dens = DensityPlanar(atomgroups=[group_H2O, group_CO2, group_CAR], 
                        bin_width = 0.25, 
                        dens = "mass",
                        refgroup = group_FLU).run()
    zcoor_1 = dens.results['bin_pos']
    dens_H2O = dens.results['profile_mean'].T[0]
    dens_CO2 = dens.results['profile_mean'].T[1]
    dens_CAR = dens.results['profile_mean'].T[2]

    # diporder profile
    dipo = Diporder(atomgroups=[group_H2O, group_CO2, group_CAR], 
                    bin_width = 0.25, 
                    refgroup = group_FLU).run()
    zcoor_2 = dipo.results['bin_pos']
    dipo_H2O = dipo.results['profile_mean'].T[0]
    dipo_CO2 = dipo.results['profile_mean'].T[1]
    dipo_CAR = dipo.results['profile_mean'].T[2]

    mypad = 10
    fig = plt.figure(figsize=(13,13))

    ax3 = plt.subplot(1, 2, 1)
    plt.plot(dens_H2O, zcoor_1/10, color=my_color_1, linewidth=4)
    plt.plot(dens_CO2, zcoor_1/10, color=my_color_2, linewidth=4)
    plt.plot(dens_CAR/4, zcoor_1/10, color=my_color_3, linewidth=4)
    plt.ylabel(r"$z$ (nm)", fontdict=font)
    plt.xlabel(r"density (amu/$\mathrm{\AA}$)", fontdict=font)
    plt.xticks(fontsize=fontsize)
    plt.yticks(fontsize=fontsize)
    #plt.xlim(0, 2.5)
    ax3.minorticks_on()
    ax3.tick_params('both', length=10, width=2, which='major', direction='in')
    ax3.tick_params('both', length=6, width=1.4, which='minor', direction='in')
    ax3.xaxis.set_ticks_position('both')
    ax3.yaxis.set_ticks_position('both')
    ax3.spines["top"].set_linewidth(2)
    ax3.spines["bottom"].set_linewidth(2)
    ax3.spines["left"].set_linewidth(2)
    ax3.spines["right"].set_linewidth(2)
    minor_locator_y = AutoMinorLocator(2)
    ax3.yaxis.set_minor_locator(minor_locator_y)
    minor_locator_x = AutoMinorLocator(2)
    ax3.xaxis.set_minor_locator(minor_locator_x)
    ax3.legend(frameon=False, fontsize=fontlegende, 
            loc='upper left', handletextpad=0.3,
            handlelength = 0.5, borderpad = 0.6, 
            labelspacing=0.6) 
    ax3.tick_params(axis='x', pad=10)

    ax3 = plt.subplot(1, 2, 2)
    plt.plot(dipo_H2O, zcoor_1/10, color=my_color_1, linewidth=4)
    plt.plot(dipo_CO2, zcoor_1/10, color=my_color_2, linewidth=4)
    plt.plot(dipo_CAR/4, zcoor_1/10, color=my_color_3, linewidth=4)
    plt.ylabel(r"$z$ (nm)", fontdict=font)
    plt.xlabel(r"diporder", fontdict=font)
    plt.xticks(fontsize=fontsize)
    plt.yticks(fontsize=fontsize)
    #plt.xlim(0, 2.5)
    ax3.minorticks_on()
    ax3.tick_params('both', length=10, width=2, which='major', direction='in')
    ax3.tick_params('both', length=6, width=1.4, which='minor', direction='in')
    ax3.xaxis.set_ticks_position('both')
    ax3.yaxis.set_ticks_position('both')
    ax3.spines["top"].set_linewidth(2)
    ax3.spines["bottom"].set_linewidth(2)
    ax3.spines["left"].set_linewidth(2)
    ax3.spines["right"].set_linewidth(2)
    minor_locator_y = AutoMinorLocator(2)
    ax3.yaxis.set_minor_locator(minor_locator_y)
    minor_locator_x = AutoMinorLocator(2)
    ax3.xaxis.set_minor_locator(minor_locator_x)
    ax3.legend(frameon=False, fontsize=fontlegende, 
            loc='upper left', handletextpad=0.3,
            handlelength = 0.5, borderpad = 0.6, 
            labelspacing=0.6) 
    ax3.tick_params(axis='x', pad=10)

    number = '{0:04d}'.format(cpt)
    name = 'figure.'+number+'.pdf'
    cpt += 1

    plt.savefig(name, bbox_inches = 'tight', pad_inches = 0.062)  
    plt.show()
# Out:
# Unwrapping in combination with atom grouping is superfluous. `unwrap` will be set to `False`.
# /home/simon/.local/lib/python3.8/site-packages/maicos/core/base.py:254: UserWarning: Your data seems to be correlated with a correlation time which is 4.00 times larger than your step size. Consider increasing your step size by a factor of 7 to get a reasonable error estimate.
#   warnings.warn("Your data seems to be correlated with a "
# /home/simon/.local/lib/python3.8/site-packages/maicos/lib/util.py:55: UserWarning: Cannot use 'molecules'. Falling back to 'fragments'
#   warnings.warn("Cannot use 'molecules'. Falling back to 'fragments'")
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Unwrapping in combination with atom grouping is superfluous. `unwrap` will be set to `False`.
# /home/simon/.local/lib/python3.8/site-packages/maicos/core/base.py:249: UserWarning: Your trajectory does not provide sufficientstatistics to estimate a correlation time.Use the calculated error estimates withcaution.
#   warnings.warn("Your trajectory does not provide sufficient"
# /home/simon/.local/lib/python3.8/site-packages/maicos/lib/util.py:55: UserWarning: Cannot use 'molecules'. Falling back to 'fragments'
#   warnings.warn("Cannot use 'molecules'. Falling back to 'fragments'")
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Unwrapping in combination with atom grouping is superfluous. `unwrap` will be set to `False`.
# /home/simon/.local/lib/python3.8/site-packages/maicos/core/base.py:249: UserWarning: Your trajectory does not provide sufficientstatistics to estimate a correlation time.Use the calculated error estimates withcaution.
#   warnings.warn("Your trajectory does not provide sufficient"
# /home/simon/.local/lib/python3.8/site-packages/maicos/lib/util.py:55: UserWarning: Cannot use 'molecules'. Falling back to 'fragments'
#   warnings.warn("Cannot use 'molecules'. Falling back to 'fragments'")
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Unwrapping in combination with atom grouping is superfluous. `unwrap` will be set to `False`.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Unwrapping in combination with atom grouping is superfluous. `unwrap` will be set to `False`.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Unwrapping in combination with atom grouping is superfluous. `unwrap` will be set to `False`.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Unwrapping in combination with atom grouping is superfluous. `unwrap` will be set to `False`.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Unwrapping in combination with atom grouping is superfluous. `unwrap` will be set to `False`.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Unwrapping in combination with atom grouping is superfluous. `unwrap` will be set to `False`.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Unwrapping in combination with atom grouping is superfluous. `unwrap` will be set to `False`.
# /home/simon/.local/lib/python3.8/site-packages/maicos/core/base.py:249: UserWarning: Your trajectory does not provide sufficientstatistics to estimate a correlation time.Use the calculated error estimates withcaution.
#   warnings.warn("Your trajectory does not provide sufficient"
# /home/simon/.local/lib/python3.8/site-packages/maicos/lib/util.py:55: UserWarning: Cannot use 'molecules'. Falling back to 'fragments'
#   warnings.warn("Cannot use 'molecules'. Falling back to 'fragments'")
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Unwrapping in combination with atom grouping is superfluous. `unwrap` will be set to `False`.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Unwrapping in combination with atom grouping is superfluous. `unwrap` will be set to `False`.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Unwrapping in combination with atom grouping is superfluous. `unwrap` will be set to `False`.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Unwrapping in combination with atom grouping is superfluous. `unwrap` will be set to `False`.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Unwrapping in combination with atom grouping is superfluous. `unwrap` will be set to `False`.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Unwrapping in combination with atom grouping is superfluous. `unwrap` will be set to `False`.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Unwrapping in combination with atom grouping is superfluous. `unwrap` will be set to `False`.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Unwrapping in combination with atom grouping is superfluous. `unwrap` will be set to `False`.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Unwrapping in combination with atom grouping is superfluous. `unwrap` will be set to `False`.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Unwrapping in combination with atom grouping is superfluous. `unwrap` will be set to `False`.
# /home/simon/.local/lib/python3.8/site-packages/maicos/core/base.py:249: UserWarning: Your trajectory does not provide sufficientstatistics to estimate a correlation time.Use the calculated error estimates withcaution.
#   warnings.warn("Your trajectory does not provide sufficient"
# /home/simon/.local/lib/python3.8/site-packages/maicos/lib/util.py:55: UserWarning: Cannot use 'molecules'. Falling back to 'fragments'
#   warnings.warn("Cannot use 'molecules'. Falling back to 'fragments'")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/MDAnalysis/lib/util.py in wrapper(self, *args, **kwargs)
#    1577                     try:
# -> 1578                         if self._cache_key not in valid_caches:
#    1579                             raise KeyError
#
# ~/.local/lib/python3.8/site-packages/MDAnalysis/core/groups.py in __getattr__(self, attr)
#    2536             raise NoDataError('This Universe has no coordinates')
# -> 2537         return super(AtomGroup, self).__getattr__(attr)
#    2538
#
# ~/.local/lib/python3.8/site-packages/MDAnalysis/core/groups.py in __getattr__(self, attr)
#     610         else:
# --> 611             return super(GroupBase, self).__getattr__(attr)
#     612
#
# ~/.local/lib/python3.8/site-packages/MDAnalysis/core/groups.py in __getattr__(self, attr)
#     386                 err += 'Did you mean {match}?'.format(match=match)
# --> 387             raise AttributeError(err)
#     388
#
# AttributeError: AtomGroup has no attribute _cache_key.
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/MDAnalysis/lib/util.py in wrapper(self, *args, **kwargs)
#    1585                         self._cache_key = _CacheKey()
# -> 1586                         raise KeyError
#    1587                 return self._cache[key]
#
# KeyError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-253a7fdb8bd9> in <module>
#      22
#      23     # diporder profile
# ---> 24     dipo = Diporder(atomgroups=[group_H2O, group_CO2, group_CAR],
#      25                     bin_width = 0.25,
#      26                     refgroup = group_FLU).run()
#
# ~/.local/lib/python3.8/site-packages/maicos/core/base.py in run(self, start, stop, step, verbose)
#     203                     groups = self.atomgroups
#     204                 for group in groups:
# --> 205                     group.unwrap(compound=get_compound(group))
#     206
#     207             timeseries[i] = self._single_frame()
#
# ~/.local/lib/python3.8/site-packages/maicos/lib/util.py in get_compound(atomgroup, return_index)
#      52         compound = "molecules"
#      53         indices = atomgroup.atoms.molnums
# ---> 54     elif hasattr(atomgroup, "fragments"):
#      55         warnings.warn("Cannot use 'molecules'. Falling back to 'fragments'")
#      56         compound = "fragments"
#
# ~/.local/lib/python3.8/site-packages/MDAnalysis/lib/util.py in wrapper(self, *args, **kwargs)
#    1587                 return self._cache[key]
#    1588             except KeyError:
# -> 1589                 self._cache[key] = ret = func(self, *args, **kwargs)
#    1590                 if universe_validation:
#    1591                     valid_caches.add(self._cache_key)
#
# ~/.local/lib/python3.8/site-packages/MDAnalysis/core/topologyattrs.py in fragments(self)
#    2711         """
#    2712         fragdict = self.universe._fragdict
# -> 2713         return tuple(sorted(set(fragdict[aix].fragment for aix in self.ix),
#    2714                             key=lambda x: x[0].ix))
#    2715
#
# ~/.local/lib/python3.8/site-packages/MDAnalysis/core/groups.py in __hash__(self)
#     569
#     570     def __hash__(self):
# --> 571         return hash((self._u, self.__class__, tuple(self.ix.tolist())))
#     572
#     573     def __len__(self):
#
# KeyboardInterrupt:
